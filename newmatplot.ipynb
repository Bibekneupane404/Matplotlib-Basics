# %%
# %matplotlib inline
from matplotlib import pyplot as plt
plt.plot([1,2,3], [2,5,7])
plt.title("Bibek's Data")
plt.ylabel("This is Y")
plt.xlabel("This is X")
plt.show()

# %%
from matplotlib import pyplot as plt
from matplotlib import style
style.use('ggplot')
x = [1,5,4]
y = [23,45,89]
x2 = [2,4,2]
y2 = [5,2,9]
plt.hist(x,y,label = "first data",linewidth = 5)
plt.plot(x2,y2, label = "second data")
plt.scatter(x2,y2, label = "third data")


plt.legend()
plt.show()
